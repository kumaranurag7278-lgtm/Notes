# %%
# Use ! prefix to run shell commands in Jupyter Notebook
# !pip install chart-studio
import chart_studio.plotly as py
# Out:
# Collecting chart-studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: plotly in d:\anaconda\lib\site-packages (from chart-studio) (6.3.0)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from chart-studio) (2.32.5)
# Collecting retrying>=1.3.3 (from chart-studio)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: six in d:\anaconda\lib\site-packages (from chart-studio) (1.17.0)
# Requirement already satisfied: narwhals>=1.15.1 in d:\anaconda\lib\site-packages (from plotly->chart-studio) (2.7.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from plotly->chart-studio) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests->chart-studio) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->chart-studio) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->chart-studio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->chart-studio) (2026.1.4)
# Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: retrying, chart-studio
#
#    -------------------- ------------------- 1/2 [chart-studio]
#    -------------------- ------------------- 1/2 [chart-studio]
#    -------------------- ------------------- 1/2 [chart-studio]
#    -------------------- ------------------- 1/2 [chart-studio]
#    ---------------------------------------- 2/2 [chart-studio]
#
# Successfully installed chart-studio-1.1.0 retrying-1.4.2
