# %%
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data = np.random.randn(100,4),columns ="A B C D".split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.346841 -1.511544  0.629441 -0.499935
# 1  0.415916 -0.651829  0.957125 -0.094433
# 2 -2.312262 -0.894125 -0.398977 -0.951009
# 3  0.599439  0.928574 -0.402319  0.099318
# 4 -0.375233 -0.311625 -1.655637 -0.651486

# %%
fig = px.scatter(df1,x="A",y = "B",color = "A",hover_data=["B"])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 fig = px.scatter(df1,x="A",y = "B",color = "A",hover_data=["B"])
#       2 fig.show()
#
# File D:\anaconda\Lib\site-packages\plotly\express\_chart_types.py:69, in scatter(data_frame, x, y, color, symbol, size, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, marginal_x, marginal_y, trendline, trendline_options, trendline_color_override, trendline_scope, log_x, log_y, range_x, range_y, render_mode, title, subtitle, template, width, height)
# ...

# %%
px.histogram(df,x="A").show()

# %%
px.line(df, x="D", y="C").show()        # Trends over time
px.bar(df, x="A", y="B").show()    # Compare categories
px.histogram(df, x="A").show()              # Distribution of one variable
px.box(df, y="A").show()                 # Spread and outliers
px.imshow(corr_matrix).show()                 # Heatmap (e.g., a correlation matrix)

# %%
fig.update_layout(xaxis_title="biggie")
fig.update_traces(marker_size=5)
fig.show()

# %%
import plotly.express as px

df1 = px.data.iris()
df1.head()

# %%
px.scatter(df1,x="sepal_length",y="petal_length",facet_col="species",color="species").show()

# %%
px.histogram(df1,
             x="petal_length",
             facet_col="species").show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       1 import plotly.graph_objects as go
#       2 fig = go.Figure()
# ----> 4 fig.add_trace(go.scatter(x=[1,2,3,4],y=[10,15,20,25]))
#       5 fig.show()
#
# TypeError: 'module' object is not callable

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=[1,2,3,4],
        y=[10,15,13,20]
    )
)

fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(
    go.Scatter(
        x=[1,2,3],
        y=[4,5,6],
        name="Series A"
    )
)

fig.add_trace(
    go.Scatter(
        x=[1,2,3],
        y=[6,2,5],
        name="Series B"
    )
)

fig.show()
